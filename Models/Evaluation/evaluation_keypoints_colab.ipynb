# %% [markdown]
# # LOAD REPO

# %%
# !git clone <GITHUB_TOKEN>@github.com/EkmalRey/FutsalCV.git
# Out:
# fatal: destination path 'FutsalCV' already exists and is not an empty directory.

# %% [markdown]
# # INSTALL REQUIREMENTS

# %%
# Install runtime dependencies (idempotent)
# %pip install -r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt
# Out:
# Requirement already satisfied: ultralytics>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 2)) (8.3.235)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 4)) (0.24.0+cu126)
# Requirement already satisfied: huggingface_hub>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 5)) (0.36.0)
# Requirement already satisfied: opencv-python>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 6)) (4.12.0.88)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 8)) (4.67.1)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 9)) (2.0.2)
# Requirement already satisfied: pillow>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 10)) (11.3.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 11)) (2.2.2)
# Requirement already satisfied: supervision>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 12)) (0.27.0)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 13)) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 2)) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 2)) (1.16.3)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 2)) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 2)) (1.31.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 2)) (2.0.18)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.19.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 5)) (25.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.19.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 7)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 7)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 7)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 11)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 11)) (2025.2)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from supervision>=0.16.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 12)) (0.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics>=8.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics>=8.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 2)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics>=8.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics>=8.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 2)) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->-r /content/FutsalCV/Resources/Notebooks/TRAINING/YOLO/requirements.txt (line 3)) (3.0.3)

# %% [markdown]
# # IMPORTS

# %%
from pathlib import Path
import json
import random
import sys
from dataclasses import dataclass
from typing import Dict, List, Optional, Tuple

import cv2
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
from ultralytics import YOLO


# Point to helper folder (sibling of this notebook)
HELPER_DIR = Path("FutsalCV") / "Resources" / "Notebooks" / "TRAINING" / "YOLO" / "Helper"
sys.path.append(str(HELPER_DIR))

from footballanalytix.config import PoseEstimationConfig
from footballanalytix.training import get_device
from _1_download_dataset import download_dataset
from _3_0_convert_raw_to_yolo_keypoints import (
    ConvertConfig,
    KEYPOINT_ORDER,
    _create_dataset_yaml,
    process_split,
)
from _4_0_train_yolo_keypoints import evaluate_keypoint_metrics
from _5_evaluation_all import reprojection_error

# %% [markdown]
# # CONFIG

# %%
PROJECT_ROOT = Path("/content/FutsalCV")
RESOURCES_DIR = PROJECT_ROOT / "Resources"
DATA_ROOT = RESOURCES_DIR / "Dataset" / "SN-GSR-2025"
YOLO_ROOT = RESOURCES_DIR / "Dataset" / "yolo_soccernet_pitch"
RESULTS_DIR = RESOURCES_DIR / "Models"
OUTPUT_DIR = Path("content") / "outputs" / "keypoints_eval_test"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Model
FIELD_MODEL_PATH = RESULTS_DIR / "fields.pt"

# Evaluation settings
SPLIT = "test"
SAMPLE_VIS_COUNT = 6
CONFIDENCE = 0.5
DEVICE = get_device()

print(f"Project root: {PROJECT_ROOT}")
print(f"Data root:    {DATA_ROOT}")
print(f"YOLO root:    {YOLO_ROOT}")
print(f"Model path:   {FIELD_MODEL_PATH}")
print(f"Device:       {DEVICE}")
# Out:
# Project root: /content/FutsalCV
# Data root:    /content/FutsalCV/Resources/Dataset/SN-GSR-2025
# YOLO root:    /content/FutsalCV/Resources/Dataset/yolo_soccernet_pitch
# Model path:   /content/FutsalCV/Resources/Models/fields.pt
# Device:       0

# %% [markdown]
# # EVALUATION PROGRAM

# %% [markdown]
# ## Dataset Download & GT Export

# %%
def ensure_yolo_dataset() -> Tuple[Path, Path]:
    base_output = YOLO_ROOT / "soccernet_pitch"
    dataset_yaml = base_output / "dataset.yaml"
    img_test_dir = base_output / "images" / SPLIT
    lbl_test_dir = base_output / "labels" / SPLIT

    def _has_files(path: Path, exts=("*.jpg", "*.png", "*.jpeg")) -> bool:
        return any(path.glob(pattern) for pattern in exts)

    if dataset_yaml.exists() and img_test_dir.exists() and lbl_test_dir.exists() and _has_files(img_test_dir) and _has_files(lbl_test_dir, ("*.txt",)):
        print("✅ YOLO dataset already present (test split)")
        return dataset_yaml, base_output

    print("⏬ Preparing dataset (test split only)...")
    cfg = PoseEstimationConfig(data_root=DATA_ROOT, yolo_root=YOLO_ROOT)
    download_dataset(cfg, debug_test_only=True)

    base_output.mkdir(parents=True, exist_ok=True)
    convert_cfg = ConvertConfig(
        data_root=cfg.data_root,
        yolo_root=YOLO_ROOT,
        splits=[SPLIT],
        max_games=None,
        max_images=None,
        overwrite=False,
        save_unified_json=False,
        convert_workers=None,
    )

    stats = process_split(convert_cfg, SPLIT, base_output)
    dataset_yaml = _create_dataset_yaml(base_output)

    # Ensure empty train/val dirs exist so YOLO yaml paths are valid even when unused
    for split_name in ("train", "val"):
        (base_output / "images" / split_name).mkdir(parents=True, exist_ok=True)
        (base_output / "labels" / split_name).mkdir(parents=True, exist_ok=True)

    if not _has_files(img_test_dir) or not _has_files(lbl_test_dir, ("*.txt",)):
        raise RuntimeError("Conversion did not produce test images/labels.")

    print(f"Conversion stats (test): {stats}")
    print(f"Dataset yaml: {dataset_yaml}")
    return dataset_yaml, base_output


data_yaml_path, yolo_data_root = ensure_yolo_dataset()
# Out:
# ✅ YOLO dataset already present (test split)

# %% [markdown]
# ## GT Preparation

# %%
def summarize_split(base: Path, split: str) -> Dict[str, int]:
    imgs = list((base / "images" / split).glob("*.jpg")) + list((base / "images" / split).glob("*.png"))
    lbls = list((base / "labels" / split).glob("*.txt"))
    return {"images": len(imgs), "labels": len(lbls)}

summary_test = summarize_split(yolo_data_root, SPLIT)
print(f"Test split: {summary_test}")
print(f"Data yaml -> {data_yaml_path}")
# Out:
# Test split: {'images': 35957, 'labels': 35957}
# Data yaml -> /content/FutsalCV/Resources/Dataset/yolo_soccernet_pitch/soccernet_pitch/dataset.yaml

# %% [markdown]
# ## Load Model

# %%
if not FIELD_MODEL_PATH.exists():
    raise FileNotFoundError(f"Missing model at {FIELD_MODEL_PATH}")

field_model = YOLO(str(FIELD_MODEL_PATH))
print(f"Loaded field model from {FIELD_MODEL_PATH}")
print(f"Model names: {field_model.model.names}")
# Out:
# Loaded field model from /content/FutsalCV/Resources/Models/fields.pt
# Model names: {0: 'pitch'}

# %%
# Pitch configuration (29-keypoint SoccerNet layout)
KEYPOINT_NAMES = {
    1: "sideline_top_left",
    2: "big_rect_left_top_pt1",
    3: "big_rect_left_top_pt2",
    4: "big_rect_left_bottom_pt1",
    5: "big_rect_left_bottom_pt2",
    6: "small_rect_left_top_pt1",
    7: "small_rect_left_top_pt2",
    8: "small_rect_left_bottom_pt1",
    9: "small_rect_left_bottom_pt2",
    10: "sideline_bottom_left",
    11: "left_semicircle_right",
    12: "center_line_top",
    13: "center_line_bottom",
    14: "center_circle_top",
    15: "center_circle_bottom",
    16: "field_center",
    17: "sideline_top_right",
    18: "big_rect_right_top_pt1",
    19: "big_rect_right_top_pt2",
    20: "big_rect_right_bottom_pt1",
    21: "big_rect_right_bottom_pt2",
    22: "small_rect_right_top_pt1",
    23: "small_rect_right_top_pt2",
    24: "small_rect_right_bottom_pt1",
    25: "small_rect_right_bottom_pt2",
    26: "sideline_bottom_right",
    27: "right_semicircle_left",
    28: "center_circle_left",
    29: "center_circle_right",
}

MINIMAP_SCALE = 0.1
MINIMAP_PADDING = 50
MINIMAP_KEYPOINT_COLOR = (255, 255, 255)

@dataclass
class SoccerPitchConfiguration:
    length: int = 12000
    width: int = 7000
    penalty_box_length: int = 1886
    penalty_box_width: int = 4140
    goal_box_length: int = 629
    goal_box_width: int = 1885
    centre_circle_radius: int = 942
    penalty_spot_distance: int = 1257

    @property
    def vertices(self) -> List[Tuple[int, int]]:
        top_penalty = (self.width - self.penalty_box_width) / 2
        bottom_penalty = self.width - top_penalty
        top_goal = (self.width - self.goal_box_width) / 2
        bottom_goal = self.width - top_goal
        center_y = self.width / 2
        arc_radius = self.centre_circle_radius
        penalty_spot = self.penalty_spot_distance
        return [
            (0, 0),
            (0, top_penalty),
            (self.penalty_box_length, top_penalty),
            (0, bottom_penalty),
            (self.penalty_box_length, bottom_penalty),
            (0, top_goal),
            (self.goal_box_length, top_goal),
            (0, bottom_goal),
            (self.goal_box_length, bottom_goal),
            (0, self.width),
            (penalty_spot + arc_radius, center_y),
            (self.length / 2, 0),
            (self.length / 2, self.width),
            (self.length / 2, center_y - arc_radius),
            (self.length / 2, center_y + arc_radius),
            (self.length / 2, center_y),
            (self.length, 0),
            (self.length, top_penalty),
            (self.length - self.penalty_box_length, top_penalty),
            (self.length, bottom_penalty),
            (self.length - self.penalty_box_length, bottom_penalty),
            (self.length, top_goal),
            (self.length - self.goal_box_length, top_goal),
            (self.length, bottom_goal),
            (self.length - self.goal_box_length, bottom_goal),
            (self.length, self.width),
            (self.length - (penalty_spot + arc_radius), center_y),
            (self.length / 2 - arc_radius, center_y),
            (self.length / 2 + arc_radius, center_y),
        ]

    edges: List[Tuple[int, int]] = None
    line_edges: List[Tuple[int, int]] = None

    def __post_init__(self) -> None:
        self.edges = [
            (1, 17), (1, 10), (17, 26), (10, 26),
            (2, 3), (4, 5), (2, 4), (3, 5),
            (6, 7), (8, 9), (6, 8), (7, 9),
            (18, 19), (20, 21), (18, 20), (19, 21),
            (22, 23), (24, 25), (22, 24), (23, 25),
            (12, 13),
        ]
        self.line_edges = [
            (1, 10), (1, 17), (17, 26), (10, 26),
            (2, 3), (2, 4), (3, 5), (4, 5),
            (6, 7), (6, 8), (7, 9), (8, 9),
            (18, 19), (18, 20), (19, 21), (20, 21),
            (22, 23), (22, 24), (23, 25), (24, 25),
            (12, 14), (13, 15), (14, 16), (15, 16),
            (14, 28), (14, 29), (15, 28), (15, 29), (28, 29),
        ]


def draw_pitch(config: SoccerPitchConfiguration, scale: float = MINIMAP_SCALE, padding: int = MINIMAP_PADDING) -> np.ndarray:
    import math

    line_color = (255, 255, 255)
    background = (34, 139, 34)
    scaled_w = int(config.width * scale)
    scaled_l = int(config.length * scale)
    scaled_circle = int(config.centre_circle_radius * scale)
    scaled_spot = int(config.penalty_spot_distance * scale)

    canvas = np.ones((scaled_w + 2 * padding, scaled_l + 2 * padding, 3), dtype=np.uint8)
    canvas[:] = background

    for start, end in config.edges:
        p1 = (int(config.vertices[start - 1][0] * scale) + padding, int(config.vertices[start - 1][1] * scale) + padding)
        p2 = (int(config.vertices[end - 1][0] * scale) + padding, int(config.vertices[end - 1][1] * scale) + padding)
        cv2.line(canvas, p1, p2, line_color, 4)

    center = (scaled_l // 2 + padding, scaled_w // 2 + padding)
    cv2.circle(canvas, center, scaled_circle, line_color, 4)

    penalty_pts = [
        (scaled_spot + padding, scaled_w // 2 + padding),
        (scaled_l - scaled_spot + padding, scaled_w // 2 + padding),
    ]
    for spot in penalty_pts:
        cv2.circle(canvas, spot, 8, line_color, -1)

    offset = (config.penalty_box_length - config.penalty_spot_distance) * scale
    clamped = min(max(offset / max(scaled_circle, 1e-6), -1.0), 1.0)
    arc_angle = math.degrees(math.acos(clamped))

    left_center = (scaled_spot + padding, scaled_w // 2 + padding)
    right_center = (scaled_l - scaled_spot + padding, scaled_w // 2 + padding)

    cv2.ellipse(canvas, left_center, (scaled_circle, scaled_circle), 0, -arc_angle, arc_angle, line_color, 4)
    cv2.ellipse(canvas, right_center, (scaled_circle, scaled_circle), 0, 180 - arc_angle, 180 + arc_angle, line_color, 4)
    return canvas


class ViewTransformer:
    def __init__(self, source: np.ndarray, target: np.ndarray) -> None:
        if source.shape != target.shape or source.shape[1] != 2:
            raise ValueError("Source and target must be Nx2 arrays")
        m, _ = cv2.findHomography(source.astype(np.float32), target.astype(np.float32))
        if m is None:
            raise ValueError("Homography matrix could not be computed")
        self.m = m

    def transform_points(self, points: np.ndarray) -> np.ndarray:
        if points.size == 0:
            return points
        reshaped = points.reshape(-1, 1, 2).astype(np.float32)
        transformed = cv2.perspectiveTransform(reshaped, self.m)
        return transformed.reshape(-1, 2).astype(np.float32)


def detect_field_keypoints(frame: np.ndarray, model: YOLO, config: SoccerPitchConfiguration, confidence: float = CONFIDENCE) -> Tuple[np.ndarray, np.ndarray]:
    result = model(frame, conf=confidence, verbose=False)[0]
    kps = getattr(result, "keypoints", None)
    if kps is None or kps.xy is None:
        return np.empty((0, 2), dtype=np.float32), np.empty((0, 2), dtype=np.float32)

    xy = kps.xy
    conf_arr = getattr(kps, "conf", None)
    xy_np = xy[0].cpu().numpy() if hasattr(xy, "cpu") else np.asarray(xy)[0]
    conf_np = conf_arr[0].cpu().numpy() if (conf_arr is not None and hasattr(conf_arr, "cpu")) else (np.asarray(conf_arr)[0] if conf_arr is not None else None)

    expected = len(config.vertices)
    xy_np = xy_np[:expected]
    if conf_np is not None:
        conf_np = conf_np[:expected]

    if xy_np.size == 0:
        return np.empty((0, 2), dtype=np.float32), np.empty((0, 2), dtype=np.float32)

    mask = conf_np > confidence if conf_np is not None else np.ones(len(xy_np), dtype=bool)
    if not mask.any():
        return np.empty((0, 2), dtype=np.float32), np.empty((0, 2), dtype=np.float32)

    pitch_vertices = np.array(config.vertices, dtype=np.float32)[: len(xy_np)]
    frame_points = xy_np[mask].astype(np.float32)
    pitch_points = pitch_vertices[mask]
    return frame_points, pitch_points


def compute_view_transformers(frame: np.ndarray, model: YOLO, config: SoccerPitchConfiguration, confidence: float = CONFIDENCE) -> Tuple[Optional[ViewTransformer], Optional[ViewTransformer], np.ndarray, np.ndarray]:
    frame_points, pitch_points = detect_field_keypoints(frame, model, config, confidence)
    if len(frame_points) < 4 or len(pitch_points) < 4:
        return None, None, frame_points, pitch_points
    forward = ViewTransformer(source=pitch_points, target=frame_points)
    inverse = ViewTransformer(source=frame_points, target=pitch_points)
    return forward, inverse, frame_points, pitch_points


def minimap_coords(x: float, y: float, scale: float = MINIMAP_SCALE, padding: int = MINIMAP_PADDING) -> Tuple[int, int]:
    return (int(x * scale) + padding, int(y * scale) + padding)


PITCH_CONFIG = SoccerPitchConfiguration()
BASE_MINIMAP = draw_pitch(PITCH_CONFIG)
print(f"Pitch vertices: {len(PITCH_CONFIG.vertices)} keypoints")
# Out:
# Pitch vertices: 29 keypoints

# %%
# Evaluate keypoints on the full test split
print("🚀 Running keypoint evaluation on test split...")
metrics_test = evaluate_keypoint_metrics(
    model=field_model,
    yolo_data_root=yolo_data_root,
    split=SPLIT,
    conf_threshold=CONFIDENCE,
    device=str(DEVICE),
    keypoint_names=KEYPOINT_ORDER,
    verbose=True,
)
metrics_path = OUTPUT_DIR / "keypoint_metrics_test.json"
metrics_path.write_text(json.dumps(metrics_test, indent=2))
print(f"✅ Saved keypoint metrics -> {metrics_path}")

# Reprojection error over the entire test split
print("\n🧮 Computing homography reprojection error on ALL test images...")
all_images = sorted((yolo_data_root / "images" / SPLIT).glob("*.jpg"))
if not all_images:
    all_images = sorted((yolo_data_root / "images" / SPLIT).glob("*.png"))
if not all_images:
    raise FileNotFoundError("No test images found for homography evaluation")

reproj_results: List[Dict[str, object]] = []
for img_path in tqdm(all_images, desc="Reprojection (all test)", unit="img"):
    frame = cv2.imread(str(img_path))
    if frame is None:
        reproj_results.append({"image": img_path.name, "status": "read_error"})
        continue

    pitch_to_frame, frame_to_pitch, frame_pts, pitch_pts = compute_view_transformers(frame, field_model, PITCH_CONFIG, confidence=CONFIDENCE)
    if pitch_to_frame is None or frame_to_pitch is None:
        reproj_results.append({"image": img_path.name, "status": "insufficient_keypoints"})
        continue

    errors, mean_err = reprojection_error(pitch_to_frame.m, pitch_pts, frame_pts)
    reproj_results.append({
        "image": img_path.name,
        "status": "ok",
        "mean_reprojection_px": mean_err,
        "num_points": len(errors),
    })

valid_all = [r for r in reproj_results if r.get("status") == "ok"]
mean_reproj_all = float(np.mean([r["mean_reprojection_px"] for r in valid_all])) if valid_all else float("nan")
summary_all = {
    "num_images": len(all_images),
    "num_valid": len(valid_all),
    "mean_reprojection_px": mean_reproj_all,
}
print(f"✅ Homography reprojection done: {summary_all}")

# Sample visualization subset (still limited for plotting)
random.seed(42)
sample_paths = random.sample(all_images, min(SAMPLE_VIS_COUNT, len(all_images)))
print(f"🖼️ Generating overlays for {len(sample_paths)} sampled frames...")

sample_results: List[Dict[str, object]] = []
for idx, img_path in enumerate(sample_paths, start=1):
    frame = cv2.imread(str(img_path))
    if frame is None:
        sample_results.append({"image": img_path.name, "status": "read_error"})
        continue

    pitch_to_frame, frame_to_pitch, frame_pts, pitch_pts = compute_view_transformers(frame, field_model, PITCH_CONFIG, confidence=CONFIDENCE)
    if pitch_to_frame is None or frame_to_pitch is None:
        sample_results.append({"image": img_path.name, "status": "insufficient_keypoints"})
        continue

    errors, mean_err = reprojection_error(pitch_to_frame.m, pitch_pts, frame_pts)
    sample_results.append({
        "image": img_path.name,
        "status": "ok",
        "mean_reprojection_px": mean_err,
        "num_points": len(errors),
    })

    # Overlay detected and template keypoints on the frame
    vis = frame.copy()
    for i, (x, y) in enumerate(frame_pts):
        cv2.circle(vis, (int(x), int(y)), 5, (0, 215, 255), -1)
        cv2.putText(vis, str(i + 1), (int(x) + 4, int(y) - 4), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)

    projected_template = pitch_to_frame.transform_points(pitch_pts)
    for x, y in projected_template:
        cv2.circle(vis, (int(x), int(y)), 4, (0, 0, 0), 1)

    minimap = BASE_MINIMAP.copy()
    detected_pitch = frame_to_pitch.transform_points(frame_pts)
    for (px, py) in detected_pitch:
        cv2.circle(minimap, minimap_coords(px, py), 8, (0, 0, 0), -1)
    for (px, py) in pitch_pts:
        cv2.circle(minimap, minimap_coords(px, py), 6, MINIMAP_KEYPOINT_COLOR, 2)

    out_frame = OUTPUT_DIR / f"sample_{idx:02d}_frame.jpg"
    out_minimap = OUTPUT_DIR / f"sample_{idx:02d}_minimap.jpg"
    cv2.imwrite(str(out_frame), vis)
    cv2.imwrite(str(out_minimap), minimap)

# Aggregate reprojection summaries
valid_samples = [r for r in sample_results if r.get("status") == "ok"]
mean_reproj_samples = float(np.mean([r["mean_reprojection_px"] for r in valid_samples])) if valid_samples else float("nan")

reproj_summary = {
    "all_images_summary": summary_all,
    "samples": sample_results,
    "mean_reprojection_px_samples": mean_reproj_samples,
    "num_valid_samples": len(valid_samples),
    "num_sampled": len(sample_results),
}

reproj_path = OUTPUT_DIR / "reprojection_samples_test.json"
reproj_path.write_text(json.dumps(reproj_summary, indent=2))
print(f"✅ Saved reprojection summary -> {reproj_path}")
# Out:
# 🚀 Running keypoint evaluation on test split...
# Starting keypoint eval: split=test, images=35957, conf=0.5, device=0
#   processed 50/35957 images...
#   processed 100/35957 images...
#   processed 150/35957 images...
#   processed 200/35957 images...
#   processed 250/35957 images...
#   processed 300/35957 images...
#   processed 350/35957 images...
#   processed 400/35957 images...
#   processed 450/35957 images...
#   processed 500/35957 images...
#   processed 550/35957 images...
#   processed 600/35957 images...
#   processed 650/35957 images...
#   processed 700/35957 images...
#   processed 750/35957 images...
#   processed 800/35957 images...
#   processed 850/35957 images...
#   processed 900/35957 images...
#   processed 950/35957 images...
#   processed 1000/35957 images...
#   processed 1050/35957 images...
#   processed 1100/35957 images...
#   processed 1150/35957 images...
#   processed 1200/35957 images...
#   processed 1250/35957 images...
#   processed 1300/35957 images...
#   processed 1350/35957 images...
#   processed 1400/35957 images...
#   processed 1450/35957 images...
#   processed 1500/35957 images...
#   processed 1550/35957 images...
#   processed 1600/35957 images...
#   processed 1650/35957 images...
#   processed 1700/35957 images...
#   processed 1750/35957 images...
#   processed 1800/35957 images...
#   processed 1850/35957 images...
#   processed 1900/35957 images...
#   processed 1950/35957 images...
#   processed 2000/35957 images...
#   processed 2050/35957 images...
#   processed 2100/35957 images...
#   processed 2150/35957 images...
#   processed 2200/35957 images...
#   processed 2250/35957 images...
#   processed 2300/35957 images...
#   processed 2350/35957 images...
#   processed 2400/35957 images...
#   processed 2450/35957 images...
#   processed 2500/35957 images...
#   processed 2550/35957 images...
#   processed 2600/35957 images...
#   processed 2650/35957 images...
#   processed 8400/35957 images...
#   processed 8450/35957 images...
#   processed 8500/35957 images...
#   processed 8550/35957 images...
#   processed 8600/35957 images...
#   processed 8650/35957 images...
#   processed 8700/35957 images...
#   processed 8750/35957 images...
#   processed 8800/35957 images...
#   processed 8850/35957 images...
#   processed 8900/35957 images...
#   processed 8950/35957 images...
#   processed 9000/35957 images...
#   processed 9050/35957 images...
#   processed 9100/35957 images...
#   processed 9150/35957 images...
#   processed 9200/35957 images...
#   processed 9250/35957 images...
#   processed 9300/35957 images...
#   processed 9350/35957 images...
#   processed 9400/35957 images...
#   processed 9450/35957 images...
#   processed 9500/35957 images...
#   processed 9550/35957 images...
#   processed 9600/35957 images...
#   processed 9650/35957 images...
#   processed 9700/35957 images...
#   processed 9750/35957 images...
#   processed 9800/35957 images...
#   processed 9850/35957 images...
#   processed 9900/35957 images...
#   processed 9950/35957 images...
#   processed 10000/35957 images...
#   processed 10050/35957 images...
#   processed 10100/35957 images...
#   processed 10150/35957 images...
#   processed 10200/35957 images...
#   processed 10250/35957 images...
#   processed 10300/35957 images...
#   processed 10350/35957 images...
#   processed 10400/35957 images...
#   processed 10450/35957 images...
#   processed 10500/35957 images...
#   processed 10550/35957 images...
#   processed 10600/35957 images...
#   processed 10650/35957 images...
#   processed 10700/35957 images...
#   processed 10750/35957 images...
#   processed 10800/35957 images...
#   processed 10850/35957 images...
#   processed 10900/35957 images...
#   processed 10950/35957 images...
#   processed 11000/35957 images...
#   processed 11050/35957 images...
#   processed 11100/35957 images...
#   processed 11150/35957 images...
#   processed 11200/35957 images...
#   processed 11250/35957 images...
#   processed 11300/35957 images...
#   processed 11350/35957 images...
#   processed 11400/35957 images...
#   processed 11450/35957 images...
#   processed 11500/35957 images...
#   processed 11550/35957 images...
#   processed 11600/35957 images...
#   processed 11650/35957 images...
#   processed 11700/35957 images...
#   processed 11750/35957 images...
#   processed 11800/35957 images...
#   processed 11850/35957 images...
#   processed 11900/35957 images...
#   processed 11950/35957 images...
#   processed 12000/35957 images...
#   processed 12050/35957 images...
#   processed 12100/35957 images...
#   processed 12150/35957 images...
#   processed 12200/35957 images...
#   processed 12250/35957 images...
#   processed 12300/35957 images...
#   processed 12350/35957 images...
#   processed 12400/35957 images...
#   processed 12450/35957 images...
#   processed 12500/35957 images...
#   processed 12550/35957 images...
#   processed 12600/35957 images...
#   processed 12650/35957 images...
#   processed 12700/35957 images...
#   processed 12750/35957 images...
#   processed 12800/35957 images...
#   processed 12850/35957 images...
#   processed 12900/35957 images...
#   processed 12950/35957 images...
#   processed 13000/35957 images...
#   processed 13050/35957 images...
#   processed 13100/35957 images...
#   processed 13150/35957 images...
#   processed 13200/35957 images...
#   processed 13250/35957 images...
#   processed 13300/35957 images...
#   processed 13350/35957 images...
#   processed 13400/35957 images...
#   processed 13450/35957 images...
#   processed 13500/35957 images...
#   processed 13550/35957 images...
#   processed 13600/35957 images...
#   processed 13650/35957 images...
#   processed 13700/35957 images...
#   processed 13750/35957 images...
#   processed 13800/35957 images...
#   processed 13850/35957 images...
#   processed 13900/35957 images...
#   processed 13950/35957 images...
#   processed 14000/35957 images...
#   processed 31050/35957 images...
#   processed 31100/35957 images...
#   processed 31150/35957 images...
#   processed 31200/35957 images...
#   processed 31250/35957 images...
#   processed 31300/35957 images...
#   processed 31350/35957 images...
#   processed 31400/35957 images...
#   processed 31450/35957 images...
#   processed 31500/35957 images...
#   processed 31550/35957 images...
#   processed 31600/35957 images...
#   processed 31650/35957 images...
#   processed 31700/35957 images...
#   processed 31750/35957 images...
#   processed 31800/35957 images...
#   processed 31850/35957 images...
#   processed 31900/35957 images...
#   processed 31950/35957 images...
#   processed 32000/35957 images...
#   processed 32050/35957 images...
#   processed 32100/35957 images...
#   processed 32150/35957 images...
#   processed 32200/35957 images...
#   processed 32250/35957 images...
#   processed 32300/35957 images...
#   processed 32350/35957 images...
#   processed 32400/35957 images...
#   processed 32450/35957 images...
#   processed 32500/35957 images...
#   processed 32550/35957 images...
#   processed 32600/35957 images...
#   processed 32650/35957 images...
#   processed 32700/35957 images...
#   processed 32750/35957 images...
#   processed 32800/35957 images...
#   processed 32850/35957 images...
#   processed 32900/35957 images...
#   processed 32950/35957 images...
#   processed 33000/35957 images...
#   processed 33050/35957 images...
#   processed 33100/35957 images...
#   processed 33150/35957 images...
#   processed 33200/35957 images...
#   processed 33250/35957 images...
#   processed 33300/35957 images...
#   processed 33350/35957 images...
#   processed 33400/35957 images...
#   processed 33450/35957 images...
#   processed 33500/35957 images...
#   processed 33550/35957 images...
#   processed 33600/35957 images...
#   processed 33650/35957 images...
#   processed 33700/35957 images...
#   processed 33750/35957 images...
#   processed 33800/35957 images...
#   processed 33850/35957 images...
#   processed 33900/35957 images...
#   processed 33950/35957 images...
#   processed 34000/35957 images...
#   processed 34050/35957 images...
#   processed 34100/35957 images...
#   processed 34150/35957 images...
#   processed 34200/35957 images...
#   processed 34250/35957 images...
#   processed 34300/35957 images...
#   processed 34350/35957 images...
#   processed 34400/35957 images...
#   processed 34450/35957 images...
#   processed 34500/35957 images...
#   processed 34550/35957 images...
#   processed 34600/35957 images...
#   processed 34650/35957 images...
#   processed 34700/35957 images...
#   processed 34750/35957 images...
#   processed 34800/35957 images...
#   processed 34850/35957 images...
#   processed 34900/35957 images...
#   processed 34950/35957 images...
#   processed 35000/35957 images...
#   processed 35050/35957 images...
#   processed 35100/35957 images...
#   processed 35150/35957 images...
#   processed 35200/35957 images...
#   processed 35250/35957 images...
#   processed 35300/35957 images...
#   processed 35350/35957 images...
#   processed 35400/35957 images...
#   processed 35450/35957 images...
#   processed 35500/35957 images...
#   processed 35550/35957 images...
#   processed 35600/35957 images...
#   processed 35650/35957 images...
#   processed 35700/35957 images...
#   processed 35750/35957 images...
#   processed 35800/35957 images...
#   processed 35850/35957 images...
#   processed 35900/35957 images...
#   processed 35950/35957 images...
# Finished inference on 35957 images; computing metrics...
#
# 📏 Keypoint Evaluation Metrics (test split, 35957 samples)
# ============================================================
#    Mean Keypoint Error (MKE): 36.13 px
#    MKE Std Dev:               61.76 px
#    MKE Median:                15.48 px
#
#    PCK@5px:  16.1%
#    PCK@10px: 35.4%
#    PCK@20px: 57.6%
#    PCK@50px: 79.7%
#
#    Total valid keypoint pairs: 226275
#
#    Per-Keypoint Breakdown (sorted by error):
#    --------------------------------------------------------
#    13 13_center_circle_top               : MKE= 12.16px  PCK@10= 60.1%
#    09 9_sideline_bottom_left             : MKE= 13.42px  PCK@10=  6.4%
#    11 11_center_line_top                 : MKE= 17.90px  PCK@10= 41.4%
#    12 12_center_line_bottom              : MKE= 18.55px  PCK@10= 29.8%
#    15 15_field_center                    : MKE= 18.98px  PCK@10= 57.0%
#    17 17_big_rect_right_top_pt1          : MKE= 22.21px  PCK@10= 38.6%
#    14 14_center_circle_bottom            : MKE= 25.41px  PCK@10= 51.5%
#    18 18_big_rect_right_top_pt2          : MKE= 28.36px  PCK@10= 37.3%
#    22 22_small_rect_right_top_pt2        : MKE= 28.37px  PCK@10= 48.1%
#    03 3_big_rect_left_bottom_pt1         : MKE= 29.88px  PCK@10= 32.5%
#    01 1_big_rect_left_top_pt1            : MKE= 30.07px  PCK@10= 35.4%
#    06 6_small_rect_left_top_pt2          : MKE= 30.79px  PCK@10= 38.4%
#    21 21_small_rect_right_top_pt1        : MKE= 31.46px  PCK@10= 50.4%
#    05 5_small_rect_left_top_pt1          : MKE= 31.80px  PCK@10= 36.4%
#    24 24_small_rect_right_bottom_pt2     : MKE= 32.88px  PCK@10= 44.5%
#    08 8_small_rect_left_bottom_pt2       : MKE= 38.01px  PCK@10= 37.0%
#    00 0_sideline_top_left                : MKE= 38.08px  PCK@10= 24.1%
#    26 26_right_semicircle_left           : MKE= 38.34px  PCK@10= 20.5%
#    07 7_small_rect_left_bottom_pt1       : MKE= 42.54px  PCK@10= 32.4%
#    23 23_small_rect_right_bottom_pt1     : MKE= 43.06px  PCK@10= 20.1%
#    19 19_big_rect_right_bottom_pt1       : MKE= 43.68px  PCK@10= 12.5%
#    16 16_sideline_top_right              : MKE= 44.65px  PCK@10= 22.7%
#    10 10_left_semicircle_right           : MKE= 46.23px  PCK@10= 23.7%
#    02 2_big_rect_left_top_pt2            : MKE= 48.60px  PCK@10= 13.8%
#    20 20_big_rect_right_bottom_pt2       : MKE= 53.70px  PCK@10= 26.1%
#    28 28_center_circle_right             : MKE= 56.30px  PCK@10= 20.4%
#    04 4_big_rect_left_bottom_pt2         : MKE= 65.58px  PCK@10= 31.1%
#    27 27_center_circle_left              : MKE= 79.27px  PCK@10= 24.0%
#    25 25_sideline_bottom_right           : N/A (no valid pairs)
# ✅ Saved keypoint metrics -> content/outputs/keypoints_eval_test/keypoint_metrics_test.json
#
# 🧮 Computing homography reprojection error on ALL test images...
# Reprojection (all test): 100%|██████████| 35957/35957 [17:36<00:00, 34.03img/s]
# ✅ Homography reprojection done: {'num_images': 35957, 'num_valid': 33654, 'mean_reprojection_px': 48.62663173915964}
# 🖼️ Generating overlays for 6 sampled frames...
# ✅ Saved reprojection summary -> content/outputs/keypoints_eval_test/reprojection_samples_test.json

# %%
# !zip -r test.zip /content/FutsalCV/Resources/Dataset/yolo_soccernet_pitch/soccernet_pitch/annotations_json/test/
# Out:
#   adding: content/FutsalCV/Resources/Dataset/yolo_soccernet_pitch/soccernet_pitch/annotations_json/test/ (stored 0%)

# %%
from google.colab import files
files.download("keypoints_eval_test.zip")
